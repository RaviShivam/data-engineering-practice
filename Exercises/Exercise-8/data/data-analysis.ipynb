# %%
import pandas as pd

df = pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
# Check for null values in columns
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                109
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 164
# DOL Vehicle ID                                         0
# Vehicle Location                                      19
# Electric Utility                                     256
# ...

# %%
# Describ numerical columns
numerical_summary = df.describe()
print("Numerical Summary:")
print(numerical_summary)
# Out:
# Numerical Summary:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  75215.000000  75215.000000    75215.000000   75215.000000
# mean   98163.616646   2019.400332       79.460427    1598.116666
# std     2506.793636      2.973578      100.167882   10314.556810
# min     1730.000000   1999.000000        0.000000       0.000000
# 25%    98052.000000   2018.000000        0.000000       0.000000
# 50%    98118.000000   2020.000000       25.000000       0.000000
# 75%    98367.000000   2022.000000      200.000000       0.000000
# max    99701.000000   2023.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          75051.000000    7.521500e+04       7.521500e+04
# mean              29.944424    2.042152e+08       5.297235e+10
# std               14.760174    8.914236e+07       1.650854e+09
# min                1.000000    4.777000e+03       2.090001e+09
# ...

# %%
# Describe categorical columns
categorical_summary = df.describe(include=['object'])
print(categorical_summary)
# Out:
#         VIN (1-10) County     City  State   Make    Model  \
# count        75215  75215    75215  75215  75215    75106
# unique        7476    119      540     35     35      119
# top     5YJYGDEE0M   King  Seattle     WA  TESLA  MODEL 3
# freq           299  40531    13714  75051  34212    14511
#
#                  Electric Vehicle Type  \
# count                            75215
# unique                               2
# top     Battery Electric Vehicle (BEV)
# freq                             58112
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# count                                              75215
# unique                                                 3
# top              Clean Alternative Fuel Vehicle Eligible
# freq                                               35819
#
#                    Vehicle Location  \
# count                         75196
# unique                          639
# top     POINT (-122.13158 47.67858)
# ...

# %%
print("number of null values in vehicle ID", df['DOL Vehicle ID'].isnull().sum())
print("number of duplicates in vehicle ID", df['DOL Vehicle ID'].duplicated().sum())
print("number of null values in VIN (1-10)", df['VIN (1-10)'].isnull().sum())
print("number of duplicates in VIN (1-10)", df['VIN (1-10)'].duplicated().sum())
# Out:
# number of null values in vehicle ID 0
# number of null values in VIN (1-10) 0
# number of duplicates values in VIN (1-10) 67739
# number of duplicates values in VIN (1-10) 73309

# %%
df.where(df.notnull(), None)
# Out:
#        VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0      5YJ3E1EB4L     Yakima        Yakima    WA        98908        2020
# 1      5YJ3E1EA7K  San Diego     San Diego    CA        92101        2019
# 2      7JRBR0FL9M       Lane        Eugene    OR        97404        2021
# 3      5YJXCBE21K     Yakima        Yakima    WA        98908        2019
# 4      5UXKT0C5XH  Snohomish       Bothell    WA        98021        2017
# ...           ...        ...           ...   ...          ...         ...
# 75210  5YJSA1E27F      Grant    Moses Lake    WA        98837        2015
# 75211  KNDC4DLC4P  Snohomish       Bothell    WA        98012        2023
# 75212  5YJSA1E55N       King          Kent    WA        98031        2022
# 75213  KNDC3DLC9N     Pierce        Graham    WA        98338        2022
# 75214  1N4AZ0CP9D     Kitsap  Port Orchard    WA        98367        2013
#
#          Make    Model                   Electric Vehicle Type  \
# ...
